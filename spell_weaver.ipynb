# %%
from Weave_my_spell import weave_my_spell

# Type your spell, for example: 'fun jam the revolution, dance dance dance guillotine and prance, suitable solution'.
# We recommend a short spell.
# Punctuation and line breaks don't matter.
my_message = input('Short Spell: ')
# Out:
# Short Spell: fun jam the revolution, dance dance dance guillotine and prance, suitable solution

# %%
weave_my_spell(my_message)
